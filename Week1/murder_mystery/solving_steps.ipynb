# %% [markdown]
# Started by searching for any murders on the day in question in the correct city. I was told that there were two witnesses and where to locate them
#
# image1.png

# %% [markdown]
# Saved a screenshot of the story to help me keep track of some information while flipping through databases
#
# image2.png

# %% [markdown]
# Searched by the name of the given street and went desc to get the last house. Witness name Morty Shapiro.
#
# image6.png

# %% [markdown]
# Found the second witness by using their street name and name. Annabel Miller
#
# image7.png

# %% [markdown]
# Now that I had the witness names I wanted to see thier statements. Joined person id to interview id then searched thier names.
#
# Morty gave me information about a gym bag, as well as a liscense plate
# Annabell gave me the time the person was at the gym as well as the date
#
# image4.png
# image7.png

# %% [markdown]
# Morty Suspects:
# Started with Morty, searched the get fit registry to look at id that included 48Z and membership status gold
#
# This gave me two possibilties Joe Gemuska and Jeremy Bowers
# I then ran a join on the people and license information where the plate number included H42W this gave me Tushar Chandra, Jeremy Bowers, and Maxine Whitley. Things were not looking good for Mr. Bowers but I needed to check with Annabells witness history to be sure.
#
# image9.png
# image13.png

# %% [markdown]
# Annabell Suspects:
# Joined the membership with member id's. Where the date was 20180109 (When Annabell was at the location) Also, did a filter to only show people at the location between when she arrived as she said they she saw the person there.
#
# Jeremy Bowers name was on this list.

# %% [markdown]
# Now that I had both witnesses pointing me to Bowers I put him in and it was correct. Case solved... or so I thought. Turns out the perp was just a hired gun. Time to get back to work.
#
# image11.png

# %% [markdown]
# Looked at the interview with Mr. Bowers and saw that he gave us the vehicle, sex, height, .... and how many times she went to see a show in December 2017.
#
# image10.png

# %% [markdown]
# Using a join I was able to connect people to liscense information. Using vehicle make and model, sex, and height I was able to get down to three names. Red Korb, Regina George and Miranda Priestly
#
# image 12.png

# %% [markdown]
# Using a join I was able to use person information with event checkins searching name of event, putting in the range for the month of December and then just seaching each of the three names.
#
# image14.png

# %% [markdown]
# Miranda was the name that pulled with the trips to the symphony... again, how lucky that the hired gun knew this information of Ms. Korb may have been looked into.
#
# image16.png

# %% [markdown]
# Macklin you did it again.
